# %% [markdown]
# # Лабораторная работа №5. Работа с временным рядом

# %% [markdown]
# Данные: цены на момент закрытия на акции компании NSRGY

# %%
# Данные
import yfinance as yf

import datetime
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# оценка качества моделей
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit 
from sklearn.metrics import mean_squared_error

# статистические методы
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
# для быстрой обработки пропусков при расчете среднего
from pandas.core.nanops import nanmean as pd_nanmean


# для интерактивного отображения прогресса в расчетах
import tqdm
from tqdm.auto import tqdm

import seaborn as sns
sns.set_theme()

from math import sqrt
import itertools
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = yf.Ticker('NSRGY').history(interval = "1wk", start
= '2002-01-01')
df.shape
# Out:
# (1111, 7)

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2002-01-01 00:00:00-05:00  12.241969  12.460166  12.058224  12.225891
# 2002-01-08 00:00:00-05:00  12.230486  12.299391   9.738452  12.115646
# 2002-01-15 00:00:00-05:00  12.287904  12.575005  11.851511  12.345325
# 2002-01-22 00:00:00-05:00  12.632425  12.862106  12.310873  12.414229
# 2002-01-29 00:00:00-05:00  12.368293  12.689845  12.219000  12.575005
#
#                             Volume  Dividends  Stock Splits
# Date
# 2002-01-01 00:00:00-05:00  1067000        0.0           0.0
# 2002-01-08 00:00:00-05:00  1725250        0.0           0.0
# 2002-01-15 00:00:00-05:00   502750        0.0           0.0
# 2002-01-22 00:00:00-05:00  1727000        0.0           0.0
# 2002-01-29 00:00:00-05:00   769750        0.0           0.0

# %% [markdown]
# Оставим данные только на момент закрытия

# %%
df = df[['Close']]

# %%
df
# Out:
#                                 Close
# Date
# 2002-01-01 00:00:00-05:00   12.225891
# 2002-01-08 00:00:00-05:00   12.115646
# 2002-01-15 00:00:00-05:00   12.345325
# 2002-01-22 00:00:00-05:00   12.414229
# 2002-01-29 00:00:00-05:00   12.575005
# ...                               ...
# 2023-03-14 00:00:00-04:00  117.559998
# 2023-03-21 00:00:00-04:00  119.849998
# 2023-03-28 00:00:00-04:00  123.000000
# 2023-04-04 00:00:00-04:00  125.220001
# 2023-04-11 00:00:00-04:00  126.099998
#
# [1111 rows x 1 columns]

# %% [markdown]
# **Построим график временного ряда**

# %%
df.Close.plot( figsize=(15,6),title= 'Цена закрытия акции', fontsize=14, color="red")
# Out:
# <AxesSubplot:title={'center':'Цена закрытия акции'}, xlabel='Date'>

# %% [markdown]
# По графику видно, что стоило вкладыватся в акции компании.
# Также ясно, что ряд не стационарен. В нём можно выразить трендовую зависимость.

# %% [markdown]
# **Тест Дикки-Фуллера на стационарность**
# Проверим на уровне значимости 0.05

# %%
dftest = adfuller(df.Close,autolag='AIC')

if dftest[1] < 0.05:
    print('p-value = %.4f. The series is likely stationary.' % dftest[1])
else:
    print('p-value = %.4f. The series is likely non-stationary.' % dftest[1])
# Out:
# p-value = 0.9927. The series is likely non-stationary.

# %%
plot_acf(df.Close, lags=104)

# %% [markdown]
# Видна очень высокая зависимость лагов

# %%
plot_pacf(df.Close, lags=24)

# %% [markdown]
# Результаты построение PACF и ACF не удовлетворительны. Сложно определить примерные значения p,q для построения ARIMA-модели.
# Предлагается для начала избавится от трендовой зависимости

# %%
df["indexs"] = range(1, len(df)+1, 1)

# %%
from sklearn.linear_model import LinearRegression

X = np.array(df["indexs"]).reshape((-1, 1))
Y = np.array(df["Close"])

model = LinearRegression().fit(X,Y)
print('Y=', model.coef_[0], '*X +', model.intercept_)
print('coefficient of determination:', model.score(X, Y))
# Out:
# Y= 0.10365038178483575 *X + -3.5519058632885887
# coefficient of determination: 0.9329182371253126

# %%
df["Close_t"] = df["Close"] - (df["indexs"] * model.coef_[0] + model.intercept_)
df
# Out:
#                                 Close  indexs    Close_t
# Date
# 2002-01-01 00:00:00-05:00   12.225891       1  15.674147
# 2002-01-08 00:00:00-05:00   12.115646       2  15.460251
# 2002-01-15 00:00:00-05:00   12.345325       3  15.586279
# 2002-01-22 00:00:00-05:00   12.414229       4  15.551534
# 2002-01-29 00:00:00-05:00   12.575005       5  15.608659
# ...                               ...     ...        ...
# 2023-03-14 00:00:00-04:00  117.559998    1107   6.370931
# 2023-03-21 00:00:00-04:00  119.849998    1108   8.557281
# 2023-03-28 00:00:00-04:00  123.000000    1109  11.603632
# 2023-04-04 00:00:00-04:00  125.220001    1110  13.719983
# 2023-04-11 00:00:00-04:00  126.099998    1111  14.496330
#
# [1111 rows x 3 columns]

# %%
df.Close_t.plot( figsize=(15,6),title= 'Без тренда', fontsize=14, color="red")
# Out:
# <AxesSubplot:title={'center':'Без тренда'}, xlabel='Date'>

# %%
dftest_t = adfuller(df.Close_t,autolag='AIC')

if dftest_t[1] < 0.05:
    print('p-value = %.4f. The series is likely stationary.' % dftest_t[1])
else:
    print('p-value = %.4f. The series is likely non-stationary.' % dftest_t[1])
# Out:
# p-value = 0.1467. The series is likely non-stationary.

# %% [markdown]
# Ряд всё ещё не стационарен, однако, значение p-value уменьшилось в разы. Добрый знак

# %%
plot_acf(df.Close_t, lags=104)

# %%
plot_pacf(df.Close_t, lags=24)

# %% [markdown]
# Нам удалось уменьшить зависимость цены акции от предыдущих значений, однако, оно всё ещё очень велико.

# %% [markdown]
# Разделим данные

# %%
from sklearn. model_selection import train_test_split

train, test = df[0:1000], df[1000:]
print(train.shape, test.shape)
# Out:
# (1000, 3) (111, 3)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
p = range(0,3)
d = range(0,3)
q = range(0,15)
pdq = list(itertools.product(p, d, q))
best_params = (0,0,0)
best_mape = np.inf

for params in tqdm(pdq):
    
    model_test = sm.tsa.arima.ARIMA(train.Close_t, order = params)
    result_test = model_test.fit()
    preds = result_test.predict(dynamic=False)

    mape_ = mean_absolute_percentage_error(train.Close_t, preds)
    if mape_ < best_mape:
        best_params = params
        best_mape = mape_
print(best_params, best_mape)
# Out:
#   0%|          | 0/135 [00:00<?, ?it/s]
# (1, 0, 2) 32.72548293904762

# %% [markdown]
# Таким образом на преобразованных данных можно построить модель ARIMA(1,0,2)

# %%
p = range(0,3)
d = range(0,3)
q = range(0,15)
pdq = list(itertools.product(p, d, q))
best_params = (0,0,0)
best_mape = np.inf

for params in tqdm(pdq):
    
    model_test = sm.tsa.arima.ARIMA(train.Close, order = params)
    result_test = model_test.fit()
    preds = result_test.predict(dynamic=False)

    mape_ = mean_absolute_percentage_error(train.Close, preds)
    if mape_ < best_mape:
        best_params = params
        best_mape = mape_
print(best_params, best_mape)
# Out:
#   0%|          | 0/135 [00:00<?, ?it/s]
# (1, 1, 7) 1.9260180477028557

# %% [markdown]
# Таким образом на исзодных данных можно построить модель ARIMA(1,1,7). Она сложнее нежели модель без тренда, однако, даёт лучшие результаты

# %% [markdown]
# Проверим модель на тестовой выборке

# %%
model_test = sm.tsa.arima.ARIMA(test.Close, order = (1,1,7))
result_test = model_test.fit()
preds = result_test.predict(dynamic=False)

print(mean_absolute_percentage_error(test.Close, preds))
# Out:
# 2.7022221114599834

# %% [markdown]
# Ошибка увеличилась не сильно
# Построим прогноз

# %%
# Получить прогноз на 10 шагов вперёд
pred_uc = result_test.get_forecast(steps=10)
# Получить интервал прогноза
pred_ci = pred_uc.conf_int()

# %%
y = pd.Series(test.Close, index=test.index)
y
# Out:
# Date
# 2021-03-02 00:00:00-05:00    100.684418
# 2021-03-09 00:00:00-05:00    102.759216
# 2021-03-16 00:00:00-04:00    105.976082
# 2021-03-23 00:00:00-04:00    106.842171
# 2021-03-30 00:00:00-04:00    108.460121
#                                 ...
# 2023-03-14 00:00:00-04:00    117.559998
# 2023-03-21 00:00:00-04:00    119.849998
# 2023-03-28 00:00:00-04:00    123.000000
# 2023-04-04 00:00:00-04:00    125.220001
# 2023-04-11 00:00:00-04:00    126.099998
# Name: Close, Length: 111, dtype: float64

# %%
print(pred_ci)
# Out:
#                            lower Close  upper Close
# 2023-04-18 00:00:00-04:00   120.953378   132.129997
# 2023-04-25 00:00:00-04:00   116.981826   133.515652
# 2023-05-02 00:00:00-04:00   114.308792   135.152188
# 2023-05-09 00:00:00-04:00   111.607353   135.712364
# 2023-05-16 00:00:00-04:00   109.140860   136.495923
# 2023-05-23 00:00:00-04:00   107.957510   137.591682
# 2023-05-30 00:00:00-04:00   106.940715   138.258902
# 2023-06-06 00:00:00-04:00   106.576624   138.718303
# 2023-06-13 00:00:00-04:00   106.070857   139.198085
# 2023-06-20 00:00:00-04:00   105.620928   139.655098

# %%
ax = y.plot(label='observed', figsize=(20, 15))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
pred_ci.iloc[:, 0],
pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Close')
plt.legend()
plt.show()

# %% [markdown]
# Судя по графику, в дальнейшем цены на акции этой компании будут снижатся

# %%
df.Close.plot( figsize=(15,6),title= 'Цена закрытия акции', fontsize=14, color="red")
# Out:
# <AxesSubplot:title={'center':'Цена закрытия акции'}, xlabel='Date'>

# %% [markdown]
# Требуется разделить исходные данные на 3 блока
# Предлагается взять такие интервалы:
# 1. Начало - середина 2008-2009 (примерный локальный максимум)
# 2. середина 2008-2009 - 2017
# 3. 2017 - конец

# %%
df_1 = df.index < '2008-06-25 00:00:00-04:00'
df_1 = df.loc[df_1]
df_1
# Out:
#                                Close  indexs    Close_t
# Date
# 2002-01-01 00:00:00-05:00  12.225891       1  15.674147
# 2002-01-08 00:00:00-05:00  12.115646       2  15.460251
# 2002-01-15 00:00:00-05:00  12.345325       3  15.586279
# 2002-01-22 00:00:00-05:00  12.414229       4  15.551534
# 2002-01-29 00:00:00-05:00  12.575005       5  15.608659
# ...                              ...     ...        ...
# 2008-05-27 00:00:00-04:00  33.660606     335   2.489634
# 2008-06-03 00:00:00-04:00  33.639027     336   2.364404
# 2008-06-10 00:00:00-04:00  32.055794     337   0.677521
# 2008-06-17 00:00:00-04:00  31.597277     338   0.115354
# 2008-06-24 00:00:00-04:00  30.504927     339  -1.080647
#
# [339 rows x 3 columns]

# %%
df_2 = df.query("index >= '2008-06-25 00:00:00-04:00' & index < '2017-01-01 00:00:00-04:00'")
df_2
# Out:
#                                Close  indexs    Close_t
# Date
# 2008-07-01 00:00:00-04:00  29.972233     340  -1.716991
# 2008-07-08 00:00:00-04:00  28.825935     341  -2.966939
# 2008-07-15 00:00:00-04:00  29.115879     342  -2.780646
# 2008-07-22 00:00:00-04:00  29.358627     343  -2.641548
# 2008-07-29 00:00:00-04:00  29.756454     344  -2.347371
# ...                              ...     ...        ...
# 2016-11-29 00:00:00-05:00  58.973251     779 -18.218490
# 2016-12-06 00:00:00-05:00  60.610920     780 -16.684472
# 2016-12-13 00:00:00-05:00  61.987251     781 -15.411791
# 2016-12-20 00:00:00-05:00  62.030804     782 -15.471889
# 2016-12-27 00:00:00-05:00  62.492489     783 -15.113854
#
# [444 rows x 3 columns]

# %%
df_3 = df.query("index > '2017-01-01 00:00:00-04:00'")
df_3
# Out:
#                                 Close  indexs    Close_t
# Date
# 2017-01-03 00:00:00-05:00   64.104012     784 -13.605982
# 2017-01-10 00:00:00-05:00   64.452454     785 -13.361190
# 2017-01-17 00:00:00-05:00   63.929798     786 -13.987496
# 2017-01-24 00:00:00-05:00   63.476830     787 -14.544115
# 2017-01-31 00:00:00-05:00   63.973354     788 -14.151241
# ...                               ...     ...        ...
# 2023-03-14 00:00:00-04:00  117.559998    1107   6.370931
# 2023-03-21 00:00:00-04:00  119.849998    1108   8.557281
# 2023-03-28 00:00:00-04:00  123.000000    1109  11.603632
# 2023-04-04 00:00:00-04:00  125.220001    1110  13.719983
# 2023-04-11 00:00:00-04:00  126.099998    1111  14.496330
#
# [328 rows x 3 columns]

# %%
train_1, test_1 = df_1[0:289], df_1[289:]
train_2, test_2 = df_2[0:377], df_2[377:]
train_3, test_3 = df_3[0:279], df_3[279:]

# %%
p = range(0,5)
d = range(0,5)
q = range(0,10)
pdq = list(itertools.product(p, d, q))
best_params = (0,0,0)
best_mape = np.inf

for params in tqdm(pdq):
    
    model_test = sm.tsa.arima.ARIMA(train_1.Close, order = params)
    result_test = model_test.fit()
    preds = result_test.predict(dynamic=False)

    mape_ = mean_absolute_percentage_error(train_1.Close, preds)
    if mape_ < best_mape:
        best_params = params
        best_mape = mape_
        
model_test = sm.tsa.arima.ARIMA(test_1.Close, order = best_params)
result_test = model_test.fit()
preds = result_test.predict(dynamic=False)

mape_ = mean_absolute_percentage_error(test_1.Close, preds)
print('Best model on 1 block:', best_params, 'mape на train:',best_mape, 'mape на test:', mape_)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Best model on 1 block: (4, 0, 5) mape на train: 1.9543672501942408 mape на test: 2.5476592152396105

# %%
p = range(0,5)
d = range(0,5)
q = range(0,10)
pdq = list(itertools.product(p, d, q))
best_params = (0,0,0)
best_mape = np.inf

for params in tqdm(pdq):
    
    model_test = sm.tsa.arima.ARIMA(train_2.Close, order = params)
    result_test = model_test.fit()
    preds = result_test.predict(dynamic=False)

    mape_ = mean_absolute_percentage_error(train_2.Close, preds)
    if mape_ < best_mape:
        best_params = params
        best_mape = mape_
        
model_test = sm.tsa.arima.ARIMA(test_2.Close, order = best_params)
result_test = model_test.fit()
preds = result_test.predict(dynamic=False)

mape_ = mean_absolute_percentage_error(test_2.Close, preds)
print('Best model on 2 block:', best_params, 'mape на train:',best_mape, 'mape на test:', mape_)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Best model on 2 block: (4, 0, 9) mape на train: 2.006830349074345 mape на test: 1.5914827869535182

# %%
p = range(0,5)
d = range(0,5)
q = range(0,10)
pdq = list(itertools.product(p, d, q))
best_params = (0,0,0)
best_mape = np.inf

for params in tqdm(pdq):
    
    model_test = sm.tsa.arima.ARIMA(train_3.Close, order = params)
    result_test = model_test.fit()
    preds = result_test.predict(dynamic=False)

    mape_ = mean_absolute_percentage_error(train_3.Close, preds)
    if mape_ < best_mape:
        best_params = params
        best_mape = mape_
        
model_test = sm.tsa.arima.ARIMA(test_3.Close, order = best_params)
result_test = model_test.fit()
preds = result_test.predict(dynamic=False)

mape_ = mean_absolute_percentage_error(test_3.Close, preds)
print('Best model on 3 block:', best_params, 'mape на train:',best_mape, 'mape на test:', mape_)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Best model on 3 block: (4, 0, 4) mape на train: 1.6827954965113716 mape на test: 1.92638577467006

# %% [markdown]
# Лучшей моделью можно считать номер 3. По мимо хороших характеристик стоит учитывать, что данные на которых она строилась являются наиболее близкими к сегодня
